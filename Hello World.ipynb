# %%
print('Hello world in Codespaces!')
# Out:
# Hello world in Codespaces!

# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '2.1.4'

# %%
# !jupyter notebook --version
# Out:
# 7.0.7

# %%
df = pd.read_csv('yellow_tripdata_2019-01.csv', nrows = 100)

# %%
df
# Out:
#     VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0          1  2019-01-01 00:46:40   2019-01-01 00:53:20                1
# 1          1  2019-01-01 00:59:47   2019-01-01 01:18:59                1
# 2          2  2018-12-21 13:48:30   2018-12-21 13:52:40                3
# 3          2  2018-11-28 15:52:25   2018-11-28 15:55:45                5
# 4          2  2018-11-28 15:56:57   2018-11-28 15:58:33                5
# ..       ...                  ...                   ...              ...
# 95         2  2019-01-01 00:02:06   2019-01-01 00:10:19                2
# 96         2  2019-01-01 00:24:57   2019-01-01 00:35:42                2
# 97         2  2019-01-01 00:46:09   2019-01-01 01:06:46                1
# 98         1  2019-01-01 00:16:07   2019-01-01 00:19:41                1
# 99         1  2019-01-01 00:23:47   2019-01-01 00:39:41                1
#
#     trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0            1.50           1                  N           151           239
# 1            2.60           1                  N           239           246
# 2            0.00           1                  N           236           236
# 3            0.00           1                  N           193           193
# 4            0.00           2                  N           193           193
# ..            ...         ...                ...           ...           ...
# 95           2.57           1                  N            45            97
# 96           2.44           1                  N           144           256
# 97           4.18           1                  N            79           263
# 98           1.00           1                  N           140           233
# 99           3.90           1                  N           229           238
#
#     payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 0              1          7.0    0.5      0.5        1.65           0.0
# 1              1         14.0    0.5      0.5        1.00           0.0
# 2              1          4.5    0.5      0.5        0.00           0.0
# 3              2          3.5    0.5      0.5        0.00           0.0
# 4              2         52.0    0.0      0.5        0.00           0.0
# ..           ...          ...    ...      ...         ...           ...
# 95             1          9.5    0.5      0.5        2.16           0.0
# 96             2         10.5    0.5      0.5        0.00           0.0
# 97             1         16.0    0.5      0.5        3.46           0.0
# 98             1          5.0    0.5      0.5        1.00           0.0
# 99             1         14.5    0.5      0.5        4.70           0.0
#
#     improvement_surcharge  total_amount  congestion_surcharge
# 0                     0.3          9.95                   NaN
# 1                     0.3         16.30                   NaN
# 2                     0.3          5.80                   NaN
# 3                     0.3          7.55                   NaN
# 4                     0.3         55.55                   NaN
# ..                    ...           ...                   ...
# 95                    0.3         12.96                   NaN
# 96                    0.3         11.80                   NaN
# 97                    0.3         20.76                   NaN
# 98                    0.3          7.30                   NaN
# 99                    0.3         20.50                   NaN
#
# [100 rows x 18 columns]

# %%
print(pd.io.sql.get_schema(df, name='yellow_taxi_data'))
# Out:
# CREATE TABLE "yellow_taxi_data" (
# "VendorID" INTEGER,
#   "tpep_pickup_datetime" TEXT,
#   "tpep_dropoff_datetime" TEXT,
#   "passenger_count" INTEGER,
#   "trip_distance" REAL,
#   "RatecodeID" INTEGER,
#   "store_and_fwd_flag" TEXT,
#   "PULocationID" INTEGER,
#   "DOLocationID" INTEGER,
#   "payment_type" INTEGER,
#   "fare_amount" REAL,
#   "extra" REAL,
#   "mta_tax" REAL,
#   "tip_amount" REAL,
#   "tolls_amount" REAL,
#   "improvement_surcharge" REAL,
#   "total_amount" REAL,
#   "congestion_surcharge" REAL
# )

# %%
pd.to_datetime(df.tpep_pickup_datetime)
# Out:
# 0    2019-01-01 00:46:40
# 1    2019-01-01 00:59:47
# 2    2018-12-21 13:48:30
# 3    2018-11-28 15:52:25
# 4    2018-11-28 15:56:57
#              ...
# 95   2019-01-01 00:02:06
# 96   2019-01-01 00:24:57
# 97   2019-01-01 00:46:09
# 98   2019-01-01 00:16:07
# 99   2019-01-01 00:23:47
# Name: tpep_pickup_datetime, Length: 100, dtype: datetime64[ns]

# %%
pd.to_datetime(df.tpep_dropoff_datetime)
# Out:
# 0    2019-01-01 00:53:20
# 1    2019-01-01 01:18:59
# 2    2018-12-21 13:52:40
# 3    2018-11-28 15:55:45
# 4    2018-11-28 15:58:33
#              ...
# 95   2019-01-01 00:10:19
# 96   2019-01-01 00:35:42
# 97   2019-01-01 01:06:46
# 98   2019-01-01 00:19:41
# 99   2019-01-01 00:39:41
# Name: tpep_dropoff_datetime, Length: 100, dtype: datetime64[ns]

# %%
df.tpep_pickup_datetime = pd.to_datetime(df.tpep_pickup_datetime)
df.tpep_dropoff_datetime = pd.to_datetime(df.tpep_dropoff_datetime)

# %%
from sqlalchemy import create_engine

# %%
pip install psycopg2
# Out:
# Requirement already satisfied: psycopg2 in /usr/local/python/3.10.13/lib/python3.10/site-packages (2.9.9)
# Note: you may need to restart the kernel to use updated packages.

# %%
engine = create_engine('postgresql://root:root@localhost:5432/ny_taxi')

# %%
engine.connect()

# %%
print(pd.io.sql.get_schema(df, name='yellow_taxi_data', con=engine))
# Out:
# CREATE TABLE yellow_taxi_data (
# 	"VendorID" BIGINT,
# 	tpep_pickup_datetime TIMESTAMP WITHOUT TIME ZONE,
# 	tpep_dropoff_datetime TIMESTAMP WITHOUT TIME ZONE,
# 	passenger_count BIGINT,
# 	trip_distance FLOAT(53),
# 	"RatecodeID" BIGINT,
# 	store_and_fwd_flag TEXT,
# 	"PULocationID" BIGINT,
# 	"DOLocationID" BIGINT,
# 	payment_type BIGINT,
# 	fare_amount FLOAT(53),
# 	extra FLOAT(53),
# 	mta_tax FLOAT(53),
# 	tip_amount FLOAT(53),
# 	tolls_amount FLOAT(53),
# 	improvement_surcharge FLOAT(53),
# 	total_amount FLOAT(53),
# 	congestion_surcharge FLOAT(53)
# )

# %%
df_iter = pd.read_csv('yellow_tripdata_2019-01.csv', iterator=True, chunksize=100000)

# %%
df = next(df_iter)

# %%
len(df)
# Out:
# 100000

# %%
df.tpep_pickup_datetime = pd.to_datetime(df.tpep_pickup_datetime)
df.tpep_dropoff_datetime = pd.to_datetime(df.tpep_dropoff_datetime)

# %%
df
# Out:
#        VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0             1  2019-01-01 00:46:40   2019-01-01 00:53:20                1
# 1             1  2019-01-01 00:59:47   2019-01-01 01:18:59                1
# 2             2  2018-12-21 13:48:30   2018-12-21 13:52:40                3
# 3             2  2018-11-28 15:52:25   2018-11-28 15:55:45                5
# 4             2  2018-11-28 15:56:57   2018-11-28 15:58:33                5
# ...         ...                  ...                   ...              ...
# 99995         2  2019-01-01 13:43:31   2019-01-01 14:02:15                1
# 99996         1  2019-01-01 13:45:41   2019-01-01 13:51:12                4
# 99997         1  2019-01-01 13:52:57   2019-01-01 14:02:20                4
# 99998         2  2019-01-01 13:11:58   2019-01-01 13:16:56                5
# 99999         2  2019-01-01 13:20:35   2019-01-01 13:36:18                5
#
#        trip_distance  RatecodeID store_and_fwd_flag  PULocationID  \
# 0               1.50           1                  N           151
# 1               2.60           1                  N           239
# 2               0.00           1                  N           236
# 3               0.00           1                  N           193
# 4               0.00           2                  N           193
# ...              ...         ...                ...           ...
# 99995           4.83           1                  N           234
# 99996           1.10           1                  N           230
# 99997           0.90           1                  N           186
# 99998           1.72           1                  N           107
# 99999           2.01           1                  N           140
#
#        DOLocationID  payment_type  fare_amount  extra  mta_tax  tip_amount  \
# 0               239             1          7.0    0.5      0.5        1.65
# 1               246             1         14.0    0.5      0.5        1.00
# 2               236             1          4.5    0.5      0.5        0.00
# 3               193             2          3.5    0.5      0.5        0.00
# 4               193             2         52.0    0.0      0.5        0.00
# ...             ...           ...          ...    ...      ...         ...
# 99995           238             1         17.0    0.0      0.5        3.56
# 99996           186             2          6.0    0.0      0.5        0.00
# 99997           170             2          7.5    0.0      0.5        0.00
# 99998           229             2          7.0    0.0      0.5        0.00
# 99999           161             1         11.5    0.0      0.5        3.08
#
#        tolls_amount  improvement_surcharge  total_amount  congestion_surcharge
# 0               0.0                    0.3          9.95                   NaN
# 1               0.0                    0.3         16.30                   NaN
# 2               0.0                    0.3          5.80                   NaN
# 3               0.0                    0.3          7.55                   NaN
# 4               0.0                    0.3         55.55                   NaN
# ...             ...                    ...           ...                   ...
# 99995           0.0                    0.3         21.36                   NaN
# 99996           0.0                    0.3          6.80                   NaN
# 99997           0.0                    0.3          8.30                   NaN
# 99998           0.0                    0.3          7.80                   NaN
# 99999           0.0                    0.3         15.38                   NaN
#
# [100000 rows x 18 columns]

# %%
df.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         1  2019-01-01 00:46:40   2019-01-01 00:53:20                1
# 1         1  2019-01-01 00:59:47   2019-01-01 01:18:59                1
# 2         2  2018-12-21 13:48:30   2018-12-21 13:52:40                3
# 3         2  2018-11-28 15:52:25   2018-11-28 15:55:45                5
# 4         2  2018-11-28 15:56:57   2018-11-28 15:58:33                5
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0            1.5           1                  N           151           239
# 1            2.6           1                  N           239           246
# 2            0.0           1                  N           236           236
# 3            0.0           1                  N           193           193
# 4            0.0           2                  N           193           193
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 0             1          7.0    0.5      0.5        1.65           0.0
# 1             1         14.0    0.5      0.5        1.00           0.0
# 2             1          4.5    0.5      0.5        0.00           0.0
# 3             2          3.5    0.5      0.5        0.00           0.0
# 4             2         52.0    0.0      0.5        0.00           0.0
#
#    improvement_surcharge  total_amount  congestion_surcharge
# 0                    0.3          9.95                   NaN
# 1                    0.3         16.30                   NaN
# 2                    0.3          5.80                   NaN
# 3                    0.3          7.55                   NaN
# 4                    0.3         55.55                   NaN

# %%
df.head().to_sql(name='yellow_taxi_data', con=engine, if_exists='replace')
# Out:
# 5

# %%
# %time df.to_sql(name='yellow_taxi_data', con=engine, if_exists='append')
# Out:
# CPU times: user 6.55 s, sys: 53.1 ms, total: 6.6 s
# Wall time: 9.52 s
# 1000

# %%
from time import time

# %%
while True:
    t_start = time()
    df = next(df_iter)
    df.tpep_pickup_datetime = pd.to_datetime(df.tpep_pickup_datetime)
    df.tpep_dropoff_datetime = pd.to_datetime(df.tpep_dropoff_datetime)
    df.to_sql(name='yellow_taxi_data', con=engine, if_exists='append')
    t_end = time()
    print('inserted another chunk..., took %.3f seconds' % (t_end - t_start))
# Out:
# inserted another chunk..., took 10.717 seconds
# inserted another chunk..., took 10.820 seconds
# inserted another chunk..., took 10.917 seconds
# inserted another chunk..., took 10.563 seconds
# inserted another chunk..., took 11.345 seconds
# inserted another chunk..., took 10.935 seconds
# inserted another chunk..., took 10.742 seconds
# inserted another chunk..., took 10.993 seconds
# inserted another chunk..., took 10.933 seconds
# inserted another chunk..., took 10.655 seconds
# inserted another chunk..., took 11.653 seconds
# inserted another chunk..., took 10.888 seconds
# inserted another chunk..., took 10.677 seconds
# inserted another chunk..., took 10.607 seconds
# inserted another chunk..., took 10.469 seconds
# inserted another chunk..., took 10.789 seconds
# inserted another chunk..., took 10.762 seconds
# inserted another chunk..., took 10.151 seconds
# inserted another chunk..., took 10.589 seconds
# inserted another chunk..., took 10.633 seconds
# inserted another chunk..., took 10.495 seconds
# inserted another chunk..., took 11.860 seconds
# inserted another chunk..., took 12.110 seconds
# inserted another chunk..., took 10.517 seconds
# inserted another chunk..., took 10.823 seconds
# inserted another chunk..., took 10.746 seconds
# inserted another chunk..., took 11.317 seconds
# inserted another chunk..., took 10.918 seconds
# inserted another chunk..., took 10.930 seconds
# inserted another chunk..., took 10.591 seconds
# inserted another chunk..., took 10.677 seconds
# inserted another chunk..., took 10.855 seconds
# inserted another chunk..., took 11.741 seconds
# inserted another chunk..., took 12.029 seconds
# inserted another chunk..., took 11.402 seconds
# inserted another chunk..., took 10.695 seconds
# inserted another chunk..., took 11.342 seconds
# inserted another chunk..., took 10.865 seconds
# inserted another chunk..., took 11.102 seconds
# inserted another chunk..., took 11.180 seconds
# inserted another chunk..., took 10.948 seconds
# inserted another chunk..., took 10.804 seconds
# inserted another chunk..., took 11.154 seconds
# inserted another chunk..., took 11.921 seconds
# inserted another chunk..., took 12.415 seconds
# inserted another chunk..., took 11.035 seconds
# inserted another chunk..., took 11.053 seconds
# inserted another chunk..., took 10.926 seconds
# inserted another chunk..., took 11.329 seconds
# inserted another chunk..., took 7.696 seconds
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[93], line 3
#       1 while True:
#       2     t_start = time()
# ----> 3     df = next(df_iter)
#       4     df.tpep_pickup_datetime = pd.to_datetime(df.tpep_pickup_datetime)
#       5     df.tpep_dropoff_datetime = pd.to_datetime(df.tpep_dropoff_datetime)
#
# File ~/.local/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1668, in TextFileReader.__next__(self)
#    1666 def __next__(self) -> DataFrame:
#    1667     try:
# -> 1668         return self.get_chunk()
#    1669     except StopIteration:
#    1670         self.close()
#
# File ~/.local/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1777, in TextFileReader.get_chunk(self, size)
#    1775         raise StopIteration
#    1776     size = min(size, self.nrows - self._currow)
# -> 1777 return self.read(nrows=size)
#
# File ~/.local/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1748, in TextFileReader.read(self, nrows)
#    1741 nrows = validate_integer("nrows", nrows)
#    1742 try:
#    1743     # error: "ParserBase" has no attribute "read"
#    1744     (
#    1745         index,
#    1746         columns,
#    1747         col_dict,
# -> 1748     ) = self._engine.read(  # type: ignore[attr-defined]
#    1749         nrows
#    1750     )
#    1751 except Exception:
#    1752     self.close()
#
# File ~/.local/lib/python3.10/site-packages/pandas/io/parsers/c_parser_wrapper.py:234, in CParserWrapper.read(self, nrows)
#     232 try:
#     233     if self.low_memory:
# --> 234         chunks = self._reader.read_low_memory(nrows)
#     235         # destructive to chunks
#     236         data = _concatenate_chunks(chunks)
#
# File parsers.pyx:868, in pandas._libs.parsers.TextReader.read_low_memory()
#
# StopIteration:
